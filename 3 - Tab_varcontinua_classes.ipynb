# %% [markdown]
# 1. Importar as bibliotecas "Pandas" e "Numpy" (Usaremos as abreviações pd e np, respectivamente, para faciliar a notação.
# Importe também a biblioteca Math.

# %%
import pandas as pd
import numpy as np
import math

# %% [markdown]
# 2. Defina a variável "arquivo" pelo nome do arquivo da planilha.
# Defina também a variável "coluna". Essa variável definirá qual a variável será considerada para a construção da tabela.

# %%
arquivo = 'exemplo tabela.xlsx'
coluna = 'Sodium (mg)'

# %% [markdown]
# 3. Leia a planilha no Phyton (para isso use o comando pd.read_excel(...) ). Dê um nome (nesse caso chamaremos de "df").

# %%
df=pd.read_excel(arquivo)
df
# Out:
#        Menu Category              Menu Items Per Serve Size  Energy (kCal)  \
# 0       Regular Menu        McVeggie™ Burger          168 g          40205
# 1       Regular Menu    McAloo Tikki Burger®          146 g          33952
# 2       Regular Menu  McSpicy™ Paneer Burger          199 g          65276
# 3       Regular Menu       Spicy Paneer Wrap          250 g          67468
# 4       Regular Menu     American Veg Burger          177 g          51217
# ..               ...                     ...            ...            ...
# 135  Condiments Menu  Tomato Ketchup Sachets            8 g           1123
# 136  Condiments Menu             Maple Syrup           30 g            864
# 137  Condiments Menu            Cheese Slice           14 g           5103
# 138  Condiments Menu              Sweet Corn           40 g           4508
# 139  Condiments Menu    Mixed Fruit Beverage         180 ml           7225
#
#      Protein (g)  Total fat (g)  Sat Fat (g)  Trans fat (g)  \
# 0           1024           1383          534             16
# 1             85           1131          427              2
# 2           2029           3945         1712             18
# 3           2096            391         1973             26
# 4            153           2345         1051             17
# ..           ...            ...          ...            ...
# 135            8           2345            0              1
# 136            0              0            0              0
# 137          306            399          289              1
# 138          147             10           22              4
# 139           65              2            2              2
#
#      Cholesterols (mg)  Total carbohydrate (g)  Total Sugars (g)  \
# 0                  249                    5654                79
# 1                  147                    5027               705
# 2                 2185                    5233               835
# 3                 4093                    5927                35
# 4                 2524                    5696               785
# ..                 ...                     ...               ...
# 135                  8                     263               233
# 136                  3                     216               162
# 137               1343                      72                54
# 138                 20                     755               254
# 139                  1                     180              1683
#
#      Added Sugars (g)  Sodium (mg)
# 0                 449        70613
# 1                 407        54534
# 2                 527       107458
# 3                 108       108746
# 4                 476       105124
# ..                ...          ...
# 135               164         7105
# 136               534          150
# 137                 0        17895
# 138                 0            4
# 139                 0          108
#
# [140 rows x 13 columns]

# %% [markdown]
# 4. Montando Tabela de classes, indicando os limites de cada classe (note que a amplitude da classe é a mesma para todas as classes)
# Neste caso precisamos antes saber o valor mínimo e o valor máximo dos dados para que todos estejam em pelo menos uma das classes.

# %%
valormin=df[coluna].min()
valormax=df[coluna].max()
print (valormin,valormax)
# Out:
# 0 239949

# %% [markdown]
# Escolhendo os limites e montando a coluna de frequência absoluta.
# NOTE QUE PARA A ESCOLHA DOS LIMITES E DA QUANTIDADE DE CLASSES DEVEMOS SEMPRE TER EM MENTE QUE A TABELA É UM RECURSO VISUAL PARA ORGANIZAÇÃO DE DADOS E NESSE CASO NÁO FAZ SENTIDO TER MUITAS LINHAS (PENSEM EM UMA QUANTIDADE DE NO MÁXIMO 10-12 LINHAS).

# %%
classes = [0,30000,60000,90000,120000, 150000,180000,210000,240000]
frequencia = pd.value_counts(pd.cut(x=df[coluna],bins=classes,include_lowest=True,right=False))
frequencia.sort_index(ascending=True)
# Out:
# /tmp/ipython-input-4249758906.py:2: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   frequencia = pd.value_counts(pd.cut(x=df[coluna],bins=classes,include_lowest=True,right=False))
# Sodium (mg)
# [0, 30000)          95
# [30000, 60000)      16
# [60000, 90000)      12
# [90000, 120000)      9
# [120000, 150000)     2
# [150000, 180000)     3
# [180000, 210000)     2
# [210000, 240000)     1
# Name: count, dtype: int64

# %% [markdown]
# 5. Montando Frequência Relativa

# %%
Freqpercentual = round(pd.value_counts(pd.cut(x=df[coluna],bins=classes,include_lowest=True,right=False),normalize=True)*100,2)
Freqpercentual.sort_index(ascending=True)
# Out:
# /tmp/ipython-input-2202019940.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   Freqpercentual = round(pd.value_counts(pd.cut(x=df[coluna],bins=classes,include_lowest=True,right=False),normalize=True)*100,2)
# Sodium (mg)
# [0, 30000)          67.86
# [30000, 60000)      11.43
# [60000, 90000)       8.57
# [90000, 120000)      6.43
# [120000, 150000)     1.43
# [150000, 180000)     2.14
# [180000, 210000)     1.43
# [210000, 240000)     0.71
# Name: proportion, dtype: float64

# %% [markdown]
# 6. Montando as colunas da frequência acumulada e da frequência relativa acumulada

# %%
#note que é necessário acumular a coluna da frequência com as classes ordenadas, isto é, usando sort_index
freqacum=np.cumsum(frequencia.sort_index())
freqacum
# Out:
# Sodium (mg)
# [0, 30000)           95
# [30000, 60000)      111
# [60000, 90000)      123
# [90000, 120000)     132
# [120000, 150000)    134
# [150000, 180000)    137
# [180000, 210000)    139
# [210000, 240000)    140
# Name: count, dtype: int64

# %%
freqpercacum=np.cumsum(Freqpercentual.sort_index())
freqpercacum
# Out:
# Sodium (mg)
# [0, 30000)           67.86
# [30000, 60000)       79.29
# [60000, 90000)       87.86
# [90000, 120000)      94.29
# [120000, 150000)     95.72
# [150000, 180000)     97.86
# [180000, 210000)     99.29
# [210000, 240000)    100.00
# Name: proportion, dtype: float64

# %% [markdown]
# 7. Arrumando a Tabela

# %%
dist_freq = pd.DataFrame({'Frequência': frequencia,'Frequência Relativa (%)':Freqpercentual,'Freq.Acum.': freqacum,'Freq.Rel.Acum. (%)':freqpercacum})
print(dist_freq)
print(f'\n      Variável:{coluna}')
print('     *Limites superiores do intervalo de classes não incluídos')
# Out:
#                   Frequência  Frequência Relativa (%)  Freq.Acum.  \
# Sodium (mg)
# [0, 30000)                95                    67.86          95
# [30000, 60000)            16                    11.43         111
# [60000, 90000)            12                     8.57         123
# [90000, 120000)            9                     6.43         132
# [120000, 150000)           2                     1.43         134
# [150000, 180000)           3                     2.14         137
# [180000, 210000)           2                     1.43         139
# [210000, 240000)           1                     0.71         140
#
#                   Freq.Rel.Acum. (%)
# Sodium (mg)
# [0, 30000)                     67.86
# [30000, 60000)                 79.29
# [60000, 90000)                 87.86
# [90000, 120000)                94.29
# [120000, 150000)               95.72
# [150000, 180000)               97.86
# [180000, 210000)               99.29
# [210000, 240000)              100.00
#
#       Variável:Sodium (mg)
#      *Limites superiores do intervalo de classes não incluídos
